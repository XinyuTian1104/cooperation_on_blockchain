# %%
from envs.game_env_multiRound import BFTblockchainModel
from matplotlib import pyplot as plt
import numpy as np
if __name__ == '__main__':
    # when threshold is smaller than 0.5
    # both H and B are larger or equal to threshold, H larger than rate, then Honest Eq.
    model = BFTblockchainModel(n = 512, R = 100, c_check = 5, c_send = 5, kappa = 1, threshold = 0.4, initial_h = 0.51)
    
    # both H and B are larger larger or equal to threshold, H smaller than rate, then Byzantine Eq.
    # model = BFTblockchainModel(n = 100, R = 100, c_check = 5, c_send = 5, kappa = 1, threshold = 0.4, initial_h = 0.49)
    # both H and B are larger larger or equal to threshold, H equal to rate, then Pooling Eq.
    # this one cannot be shown in code.
    # model = BFTblockchainModel(n = 100, R = 100, c_check = 5, c_send = 5, kappa = 1, threshold = 0.4, initial_h = 96/191)
    
    ax, fig = plt.subplots(figsize=(20, 10))
    model.setup();
    plt.scatter([model.counter for _ in range(100)], [0 for i in range(100)], color = 'black')
    p=[0.6]
    c=[0]
    rounds_h = []
    rounds_b = []
    rewards_h = []
    rewards_b = []
    while model.terminate == False:
        model.step()
        r_honest = model.r_honest_at_round
        r_byzantine = model.r_byzantine_at_round
        rewards_h += r_honest
        rewards_b += r_byzantine
        rounds_h += [model.counter for _ in range(len(r_honest))]
        rounds_b += [model.counter for _ in range(len(r_byzantine))]

        p.append(model.proportion_of_honest)
        c.append(model.counter)
    rewards_h = np.array(rewards_h) / 100
    rewards_b = np.array(rewards_b) / 100

    plt.scatter(rounds_h, rewards_h, color = 'blue', label = 'rewards of honest')
    plt.scatter(rounds_b, rewards_b, color = 'red', label = 'rewards of byzantine')
    plt.plot(c, p, color = 'green', label = 'proportion of honest')
    ax.legend(loc = 'upper right')
    plt.grid(True)
# Out:
# The total rewards of Honest at round  1  is:  10927.727999999943 The total rewards of Byzantine at round  1  is:  10704.430000000004
# tmp:  0.5051612511336119
# total_r_honest:  10927.727999999943 total_r_byzantine:  10704.430000000004
# The probability of being honest:  0.5027911960053498
# The proportion of honest:  0.509765625
# The total rewards of Honest at round  2  is:  11187.503999999934 The total rewards of Byzantine at round  2  is:  10452.895000000064
# tmp:  0.516973092778924
# total_r_honest:  11187.503999999934 total_r_byzantine:  10452.895000000064
# The probability of being honest:  0.5091815802641866
# The proportion of honest:  0.486328125
# The total rewards of Honest at round  3  is:  10290.672000000017 The total rewards of Byzantine at round  3  is:  11352.395000000059
# tmp:  0.47547198370729904
# total_r_honest:  10290.672000000017 total_r_byzantine:  11352.395000000059
# The probability of being honest:  0.48673157837537945
# The proportion of honest:  0.509765625
# The total rewards of Honest at round  4  is:  11012.111999999941 The total rewards of Byzantine at round  4  is:  10619.810000000005
# tmp:  0.5090676639828845
# total_r_honest:  11012.111999999941 total_r_byzantine:  10619.810000000005
# The probability of being honest:  0.5049036177778846
# The proportion of honest:  0.521484375
# The total rewards of Honest at round  5  is:  12367.439999999955 The total rewards of Byzantine at round  5  is:  9365.125000000042
# tmp:  0.5690741060707725
# total_r_honest:  12367.439999999955 total_r_byzantine:  9365.125000000042
# The probability of being honest:  0.5374586205540706
# The proportion of honest:  0.533203125
# The total rewards of Honest at round  6  is:  12278.448000000028 The total rewards of Byzantine at round  6  is:  9453.645000000031
# tmp:  0.5649915081810111
# total_r_honest:  12278.448000000028 total_r_byzantine:  9453.645000000031
# The probability of being honest:  0.5352514550147285
# The proportion of honest:  0.521484375
# The total rewards of Honest at round  7  is:  11495.952000000001 The total rewards of Byzantine at round  7  is:  10156.474999999986
# tmp:  0.5309313362423532
# total_r_honest:  11495.952000000001 total_r_byzantine:  10156.474999999986
# The probability of being honest:  0.5167372067440154
# The proportion of honest:  0.505859375
# The total rewards of Honest at round  8  is:  11176.36800000001 The total rewards of Byzantine at round  8  is:  10464.080000000004
# tmp:  0.5164573302733845
# total_r_honest:  11176.36800000001 total_r_byzantine:  10464.080000000004
# The probability of being honest:  0.5089026590196004
# The proportion of honest:  0.509765625
# The total rewards of Honest at round  9  is:  11312.783999999947 The total rewards of Byzantine at round  9  is:  10333.670000000015
# tmp:  0.5226160367882872
# total_r_honest:  11312.783999999947 total_r_byzantine:  10333.670000000015
# The probability of being honest:  0.5122364812066189
# The proportion of honest:  0.482421875
# The total rewards of Honest at round  10  is:  9591.504000000043 The total rewards of Byzantine at round  10  is:  12093.275000000047
# tmp:  0.44231504503688984
# total_r_honest:  9591.504000000043 total_r_byzantine:  12093.275000000047
# The probability of being honest:  0.4687685754371111
# The proportion of honest:  0.4296875
# The total rewards of Honest at round  11  is:  7761.599999999984 The total rewards of Byzantine at round  11  is:  14351.79999999993
# tmp:  0.35099080195718496
# total_r_honest:  7761.599999999984 total_r_byzantine:  14351.79999999993
# The probability of being honest:  0.4183598524804614
# The proportion of honest:  0.431640625
# The total rewards of Honest at round  12  is:  7584.719999999979 The total rewards of Byzantine at round  12  is:  14579.100000000071
# tmp:  0.3422117667441787
# total_r_honest:  7584.719999999979 total_r_byzantine:  14579.100000000071
# The probability of being honest:  0.41345056450880135
# The proportion of honest:  0.396484375
# The total rewards of Honest at round  13  is:  -124.23599999999954 The total rewards of Byzantine at round  13  is:  16420.259999999933
# tmp:  -0.007623700112370971
# total_r_honest:  -124.23599999999954 total_r_byzantine:  16420.259999999933
# The probability of being honest:  0.30423219118249595
# The proportion of honest:  0.310546875
# TERMINATED! The final proportion of honest is:  0 The total rounds of game is:  13

# %%
from envs.game_env_multiRound import BFTblockchainModel
from matplotlib import pyplot as plt
import numpy as np
if __name__ == '__main__':
    # when threshold is smaller than 0.5
    # both H and B are larger or equal to threshold, H larger than rate, then Honest Eq.
    # model = BFTblockchainModel(n = 100, R = 100, c_check = 5, c_send = 5, kappa = 1, threshold = 0.4, initial_h = 0.6)
    # both H and B are larger larger or equal to threshold, H smaller than rate, then Byzantine Eq.
    # model = BFTblockchainModel(n = 100, R = 100, c_check = 5, c_send = 5, kappa = 1, threshold = 0.4, initial_h = 0.45)
    model = BFTblockchainModel(n = 512, R = 100, c_check = 5, c_send = 5, kappa = 1, threshold = 0.4, initial_h = 0.5)
    
    # both H and B are larger larger or equal to threshold, H equal to rate, then Pooling Eq.
    # this one cannot be shown in code.
    # model = BFTblockchainModel(n = 100, R = 100, c_check = 5, c_send = 5, kappa = 1, threshold = 0.4, initial_h = 96/191)
    
    ax, fig = plt.subplots(figsize=(20, 10))
    model.setup();
    plt.scatter([model.counter for _ in range(100)], [0 for i in range(100)], color = 'black')
    p=[0.5]
    c=[0]
    rounds_h = []
    rounds_b = []
    rewards_h = []
    rewards_b = []
    while model.terminate == False:
        model.step()
        r_honest = model.r_honest_at_round
        r_byzantine = model.r_byzantine_at_round
        rewards_h += r_honest
        rewards_b += r_byzantine
        rounds_h += [model.counter for _ in range(len(r_honest))]
        rounds_b += [model.counter for _ in range(len(r_byzantine))]

        p.append(model.proportion_of_honest)
        c.append(model.counter)
    rewards_h = np.array(rewards_h) / 100
    rewards_b = np.array(rewards_b) / 100

    plt.scatter(rounds_h, rewards_h, color = 'blue', label = 'rewards of honest')
    plt.scatter(rounds_b, rewards_b, color = 'red', label = 'rewards of byzantine')
    plt.plot(c, p, color = 'green', label = 'proportion of honest')
    ax.legend(loc = 'upper right')
    plt.grid(True)
# Out:
# The total rewards of Honest at round  1  is:  9844.607999999982 The total rewards of Byzantine at round  1  is:  11821.920000000038
# tmp:  0.45436943104128047
# total_r_honest:  9844.607999999982 total_r_byzantine:  11821.920000000038
# The probability of being honest:  0.4753037126870858
# The proportion of honest:  0.48828125
# The total rewards of Honest at round  2  is:  10667.999999999989 The total rewards of Byzantine at round  2  is:  10960.769999999948
# tmp:  0.4932319313580948
# total_r_honest:  10667.999999999989 total_r_byzantine:  10960.769999999948
# The probability of being honest:  0.49634044034903685
# The proportion of honest:  0.498046875
# The total rewards of Honest at round  3  is:  10685.520000000071 The total rewards of Byzantine at round  3  is:  10946.914999999974
# tmp:  0.49395826221135297
# total_r_honest:  10685.520000000071 total_r_byzantine:  10946.914999999974
# The probability of being honest:  0.49673260901073435
# The proportion of honest:  0.490234375
# The total rewards of Honest at round  4  is:  10590.19199999995 The total rewards of Byzantine at round  4  is:  11042.91
# tmp:  0.48953645205389296
# total_r_honest:  10590.19199999995 total_r_byzantine:  11042.91
# The probability of being honest:  0.49434126661829175
# The proportion of honest:  0.5078125
# The total rewards of Honest at round  5  is:  11893.440000000024 The total rewards of Byzantine at round  5  is:  9776.340000000015
# tmp:  0.5488491346012744
# total_r_honest:  11893.440000000024 total_r_byzantine:  9776.340000000015
# The probability of being honest:  0.5264390665118629
# The proportion of honest:  0.54296875
# The total rewards of Honest at round  6  is:  12903.647999999945 The total rewards of Byzantine at round  6  is:  8922.420000000004
# tmp:  0.5912035094914931
# total_r_honest:  12903.647999999945 total_r_byzantine:  8922.420000000004
# The probability of being honest:  0.5496016674073431
# The proportion of honest:  0.5234375
# The total rewards of Honest at round  7  is:  11719.103999999941 The total rewards of Byzantine at round  7  is:  9952.760000000031
# tmp:  0.5407520091488188
# total_r_honest:  11719.103999999941 total_r_byzantine:  9952.760000000031
# The probability of being honest:  0.5220649597729832
# The proportion of honest:  0.521484375
# The total rewards of Honest at round  8  is:  11880.431999999948 The total rewards of Byzantine at round  8  is:  9807.35000000001
# tmp:  0.5477937762376979
# total_r_honest:  11880.431999999948 total_r_byzantine:  9807.35000000001
# The probability of being honest:  0.5258903482860332
# The proportion of honest:  0.5234375
# The total rewards of Honest at round  9  is:  12568.128000000044 The total rewards of Byzantine at round  9  is:  9187.82
# tmp:  0.5776869847271201
# total_r_honest:  12568.128000000044 total_r_byzantine:  9187.82
# The probability of being honest:  0.5421535504945867
# The proportion of honest:  0.50390625
# The total rewards of Honest at round  10  is:  11133.21600000001 The total rewards of Byzantine at round  10  is:  10505.440000000004
# tmp:  0.5145058916783003
# total_r_honest:  11133.21600000001 total_r_byzantine:  10505.440000000004
# The probability of being honest:  0.5078465557712323
# The proportion of honest:  0.47265625
# The total rewards of Honest at round  11  is:  9652.896000000017 The total rewards of Byzantine at round  11  is:  12039.30000000003
# tmp:  0.44499395081991683
# total_r_honest:  9652.896000000017 total_r_byzantine:  12039.30000000003
# The probability of being honest:  0.4702052913237293
# The proportion of honest:  0.46875
# The total rewards of Honest at round  12  is:  8974.07999999997 The total rewards of Byzantine at round  12  is:  12800.319999999982
# tmp:  0.4121390256447935
# total_r_honest:  8974.07999999997 total_r_byzantine:  12800.319999999982
# The probability of being honest:  0.4523173445792632
# The proportion of honest:  0.4921875
# The total rewards of Honest at round  13  is:  10051.776000000025 The total rewards of Byzantine at round  13  is:  11593.400000000029
# tmp:  0.4643887395510205
# total_r_honest:  10051.776000000025 total_r_byzantine:  11593.400000000029
# The probability of being honest:  0.48073923556005993
# The proportion of honest:  0.474609375
# The total rewards of Honest at round  14  is:  9156.24000000003 The total rewards of Byzantine at round  14  is:  12582.47499999994
# tmp:  0.4211950890381535
# total_r_honest:  9156.24000000003 total_r_byzantine:  12582.47499999994
# The probability of being honest:  0.457276497861215
# The proportion of honest:  0.4921875
# The total rewards of Honest at round  15  is:  9640.512000000006 The total rewards of Byzantine at round  15  is:  12013.299999999985
# tmp:  0.44521084786364684
# total_r_honest:  9640.512000000006 total_r_byzantine:  12013.299999999985
# The probability of being honest:  0.47037489039441505
# The proportion of honest:  0.451171875
# The total rewards of Honest at round  16  is:  9258.479999999987 The total rewards of Byzantine at round  16  is:  12476.399999999938
# tmp:  0.4259733663125823
# total_r_honest:  9258.479999999987 total_r_byzantine:  12476.399999999938
# The probability of being honest:  0.4598625509244798
# The proportion of honest:  0.48828125
# The total rewards of Honest at round  17  is:  10115.999999999987 The total rewards of Byzantine at round  17  is:  11533.240000000073
# tmp:  0.46726813504769493
# total_r_honest:  10115.999999999987 total_r_byzantine:  11533.240000000073
# The probability of being honest:  0.4822919093644604
# The proportion of honest:  0.501953125
# The total rewards of Honest at round  18  is:  11386.128000000019 The total rewards of Byzantine at round  18  is:  10256.099999999984
# tmp:  0.5261070163386143
# total_r_honest:  11386.128000000019 total_r_byzantine:  10256.099999999984
# The probability of being honest:  0.5141215933756641
# The proportion of honest:  0.513671875
# The total rewards of Honest at round  19  is:  11172.239999999929 The total rewards of Byzantine at round  19  is:  10464.224999999951
# tmp:  0.5163616145243685
# total_r_honest:  11172.239999999929 total_r_byzantine:  10464.224999999951
# The probability of being honest:  0.5088492633515719
# The proportion of honest:  0.494140625
# The total rewards of Honest at round  20  is:  10261.68000000001 The total rewards of Byzantine at round  20  is:  11376.574999999972
# tmp:  0.47423787176923543
# total_r_honest:  10261.68000000001 total_r_byzantine:  11376.574999999972
# The probability of being honest:  0.4860674202442605
# The proportion of honest:  0.474609375
# The total rewards of Honest at round  21  is:  9412.848000000007 The total rewards of Byzantine at round  21  is:  12301.369999999923
# tmp:  0.43348777285003026
# total_r_honest:  9412.848000000007 total_r_byzantine:  12301.369999999923
# The probability of being honest:  0.4639561062226763
# The proportion of honest:  0.470703125
# The total rewards of Honest at round  22  is:  9404.784000000009 The total rewards of Byzantine at round  22  is:  12315.594999999954
# tmp:  0.43299354951403124
# total_r_honest:  9404.784000000009 total_r_byzantine:  12315.594999999954
# The probability of being honest:  0.46367895273577353
# The proportion of honest:  0.466796875
# The total rewards of Honest at round  23  is:  9808.560000000029 The total rewards of Byzantine at round  23  is:  11861.850000000037
# tmp:  0.4526245696320466
# total_r_honest:  9808.560000000029 total_r_byzantine:  11861.850000000037
# The probability of being honest:  0.47435639467674384
# The proportion of honest:  0.458984375
# The total rewards of Honest at round  24  is:  9102.960000000001 The total rewards of Byzantine at round  24  is:  12667.20999999992
# tmp:  0.41813913258371593
# total_r_honest:  9102.960000000001 total_r_byzantine:  12667.20999999992
# The probability of being honest:  0.4555644178406535
# The proportion of honest:  0.453125
# The total rewards of Honest at round  25  is:  8519.040000000014 The total rewards of Byzantine at round  25  is:  13363.000000000065
# tmp:  0.3893165353870106
# total_r_honest:  8519.040000000014 total_r_byzantine:  13363.000000000065
# The probability of being honest:  0.4397447594873872
# The proportion of honest:  0.4296875
# The total rewards of Honest at round  26  is:  7740.48000000003 The total rewards of Byzantine at round  26  is:  14379.540000000085
# tmp:  0.34993096751268715
# total_r_honest:  7740.48000000003 total_r_byzantine:  14379.540000000085
# The probability of being honest:  0.4177655041897114
# The proportion of honest:  0.38671875
# The total rewards of Honest at round  27  is:  -119.39399999999961 The total rewards of Byzantine at round  27  is:  16417.48999999996
# tmp:  -0.007325640982848542
# total_r_honest:  -119.39399999999961 total_r_byzantine:  16417.48999999996
# The probability of being honest:  0.30431276067638463
# The proportion of honest:  0.310546875
# TERMINATED! The final proportion of honest is:  0 The total rounds of game is:  27

# %%
from envs.game_env_multiRound import BFTblockchainModel
from matplotlib import pyplot as plt
import numpy as np
if __name__ == '__main__':
    # when threshold is 0.5
    # both H and B are 0.5, then Byzantine Eq. (because H is smaller than rate)
    model = BFTblockchainModel(n = 512, R = 100, c_check = 5, c_send = 5, kappa = 1, threshold = 0.5, initial_h = 0.5)
    # H larger than 0.5, then Honest Eq.
    # model = BFTblockchainModel(n = 100, R = 100, c_check = 5, c_send = 5, kappa = 1, threshold = 0.5, initial_h = 0.6)
    # B larger than 0.5, then Byzantine Eq.
    # model = BFTblockchainModel(n = 100, R = 100, c_check = 5, c_send = 5, kappa = 1, threshold = 0.5, initial_h = 0.4)

    ax, fig = plt.subplots(figsize=(20, 10))
    model.setup();
    plt.scatter([model.counter for _ in range(100)], [0 for i in range(100)], color = 'black')
    p=[0.5]
    c=[0]
    rounds_h = []
    rounds_b = []
    rewards_h = []
    rewards_b = []
    while model.terminate == False:
        model.step()
        r_honest = model.r_honest_at_round
        r_byzantine = model.r_byzantine_at_round
        rewards_h += r_honest
        rewards_b += r_byzantine
        rounds_h += [model.counter for _ in range(len(r_honest))]
        rounds_b += [model.counter for _ in range(len(r_byzantine))]

        p.append(model.proportion_of_honest)
        c.append(model.counter)
    rewards_h = np.array(rewards_h) / 100
    rewards_b = np.array(rewards_b) / 100

    plt.scatter(rounds_h, rewards_h, color = 'blue', label = 'rewards of honest')
    plt.scatter(rounds_b, rewards_b, color = 'red', label = 'rewards of byzantine')
    plt.plot(c, p, color = 'green', label = 'proportion of honest')
    ax.legend(loc = 'upper right')
    plt.grid(True)
# Out:
# The total rewards of Honest at round  1  is:  10836.0 The total rewards of Byzantine at round  1  is:  10795.0
# tmp:  0.5009477139290832
# total_r_honest:  10836.0 total_r_byzantine:  10795.0
# The probability of being honest:  0.5005124998205183
# The proportion of honest:  0.484375
# The total rewards of Honest at round  2  is:  -129.45600000000053 The total rewards of Byzantine at round  2  is:  11771.76000000003
# tmp:  -0.011119448521529776
# total_r_honest:  -129.45600000000053 total_r_byzantine:  11771.76000000003
# The probability of being honest:  0.3554745161383245
# The proportion of honest:  0.357421875
# TERMINATED! The final proportion of honest is:  0 The total rounds of game is:  2

# %%
from envs.game_env_multiRound import BFTblockchainModel
from matplotlib import pyplot as plt
import numpy as np
if __name__ == '__main__':
    # when threshold is 0.5
    # both H and B are 0.5, then Byzantine Eq. (because H is smaller than rate)
    # model = BFTblockchainModel(n = 100, R = 100, c_check = 5, c_send = 5, kappa = 1, threshold = 0.5, initial_h = 0.5)
    # H larger than 0.5, then Honest Eq.
    model = BFTblockchainModel(n = 512, R = 100, c_check = 5, c_send = 5, kappa = 1, threshold = 0.5, initial_h = 0.51)
    # B larger than 0.5, then Byzantine Eq.
    # model = BFTblockchainModel(n = 100, R = 100, c_check = 5, c_send = 5, kappa = 1, threshold = 0.5, initial_h = 0.4)

    ax, fig = plt.subplots(figsize=(20, 10))
    model.setup();
    plt.scatter([model.counter for _ in range(100)], [0 for i in range(100)], color = 'black')
    p=[0.51]
    c=[0]
    rounds_h = []
    rounds_b = []
    rewards_h = []
    rewards_b = []
    while model.terminate == False:
        model.step()
        r_honest = model.r_honest_at_round
        r_byzantine = model.r_byzantine_at_round
        rewards_h += r_honest
        rewards_b += r_byzantine
        rounds_h += [model.counter for _ in range(len(r_honest))]
        rounds_b += [model.counter for _ in range(len(r_byzantine))]

        p.append(model.proportion_of_honest)
        c.append(model.counter)
    rewards_h = np.array(rewards_h) / 100
    rewards_b = np.array(rewards_b) / 100

    plt.scatter(rounds_h, rewards_h, color = 'blue', label = 'rewards of honest')
    plt.scatter(rounds_b, rewards_b, color = 'red', label = 'rewards of byzantine')
    plt.plot(c, p, color = 'green', label = 'proportion of honest')
    ax.legend(loc = 'upper right')
    plt.grid(True)
# Out:
# The total rewards of Honest at round  1  is:  10529.569999999985 The total rewards of Byzantine at round  1  is:  0.0
# tmp:  1.0
# total_r_honest:  10529.569999999985 total_r_byzantine:  0.0
# The probability of being honest:  0.628661404171865
# The proportion of honest:  0.66015625
# TERMINATED! The final proportion of honest is:  1 The total rounds of game is:  1

# %%
from envs.game_env_multiRound import BFTblockchainModel
from matplotlib import pyplot as plt
import numpy as np
if __name__ == '__main__':
    # when threshold is 0.5
    # both H and B are 0.5, then Byzantine Eq. (because H is smaller than rate)
    # model = BFTblockchainModel(n = 100, R = 100, c_check = 5, c_send = 5, kappa = 1, threshold = 0.5, initial_h = 0.5)
    # H larger than 0.5, then Honest Eq.
    # model = BFTblockchainModel(n = 100, R = 100, c_check = 5, c_send = 5, kappa = 1, threshold = 0.5, initial_h = 0.6)
    # B larger than 0.5, then Byzantine Eq.
    model = BFTblockchainModel(n = 100, R = 100, c_check = 5, c_send = 5, kappa = 1, threshold = 0.5, initial_h = 0.48)

    ax, fig = plt.subplots(figsize=(20, 10))
    model.setup();
    plt.scatter([model.counter for _ in range(100)], [0 for i in range(100)], color = 'black')
    p=[0.48]
    c=[0]
    rounds_h = []
    rounds_b = []
    rewards_h = []
    rewards_b = []
    while model.terminate == False:
        model.step()
        r_honest = model.r_honest_at_round
        r_byzantine = model.r_byzantine_at_round
        rewards_h += r_honest
        rewards_b += r_byzantine
        rounds_h += [model.counter for _ in range(len(r_honest))]
        rounds_b += [model.counter for _ in range(len(r_byzantine))]

        p.append(model.proportion_of_honest)
        c.append(model.counter)
    rewards_h = np.array(rewards_h) / 100
    rewards_b = np.array(rewards_b) / 100

    plt.scatter(rounds_h, rewards_h, color = 'blue', label = 'rewards of honest')
    plt.scatter(rounds_b, rewards_b, color = 'red', label = 'rewards of byzantine')
    plt.plot(c, p, color = 'green', label = 'proportion of honest')
    ax.legend(loc = 'upper right')
    plt.grid(True)
# Out:
# The total rewards of Honest at round  1  is:  -23.739000000000015 The total rewards of Byzantine at round  1  is:  2950.295000000004
# tmp:  -0.008111582351405536
# total_r_honest:  -23.739000000000015 total_r_byzantine:  2950.295000000004
# The probability of being honest:  0.46289292638642815
# The proportion of honest:  0.5
# TERMINATED! The final proportion of honest is:  0 The total rounds of game is:  1

# %%
from envs.game_env_multiRound import BFTblockchainModel
if __name__ == '__main__':
    # when threshold is larger than 0.5
    # H larger than threshold, then Honest Eq.
    model = BFTblockchainModel(n = 100, R = 100, c_check = 5, c_send = 5, kappa = 1, threshold = 0.55, initial_h = 0.6)
    # B larger than threshold, then Byzantine Eq.
    # model = BFTblockchainModel(n = 100, R = 100, c_check = 5, c_send = 5, kappa = 1, threshold = 0.55, initial_h = 0.4)
    
    ax, fig = plt.subplots(figsize=(20, 10))
    model.setup();
    plt.scatter([model.counter for _ in range(100)], [0 for i in range(100)], color = 'black')
    p=[0.6]
    c=[0]
    rounds_h = []
    rounds_b = []
    rewards_h = []
    rewards_b = []
    while model.terminate == False:
        model.step()
        r_honest = model.r_honest_at_round
        r_byzantine = model.r_byzantine_at_round
        rewards_h += r_honest
        rewards_b += r_byzantine
        rounds_h += [model.counter for _ in range(len(r_honest))]
        rounds_b += [model.counter for _ in range(len(r_byzantine))]

        p.append(model.proportion_of_honest)
        c.append(model.counter)
    rewards_h = np.array(rewards_h) / 100
    rewards_b = np.array(rewards_b) / 100

    plt.scatter(rounds_h, rewards_h, color = 'blue', label = 'rewards of honest')
    plt.scatter(rounds_b, rewards_b, color = 'red', label = 'rewards of byzantine')
    plt.plot(c, p, color = 'green', label = 'proportion of honest')
    ax.legend(loc = 'upper right')
    plt.grid(True)
    
    # x_list = [];
    # step_list = [];
    # model.setup();
    # while model.terminate == False:
    #     # print("not terminated")
    #     model.step();
    #     x_list.append(model.proportion_of_honest);
    #     step_list.append(model.counter);

# %%
from envs.game_env_multiRound import BFTblockchainModel
if __name__ == '__main__':
    # when threshold is larger than 0.5
    # H larger than threshold, then Honest Eq.
    # model = BFTblockchainModel(n = 100, R = 100, c_check = 5, c_send = 5, kappa = 1, threshold = 0.55, initial_h = 0.6)
    # B larger than threshold, then Byzantine Eq.
    model = BFTblockchainModel(n = 100, R = 100, c_check = 5, c_send = 5, kappa = 1, threshold = 0.55, initial_h = 0.4)
    
    ax, fig = plt.subplots(figsize=(20, 10))
    model.setup();
    plt.scatter([model.counter for _ in range(100)], [0 for i in range(100)], color = 'black')
    p=[0.4]
    c=[0]
    rounds_h = []
    rounds_b = []
    rewards_h = []
    rewards_b = []
    while model.terminate == False:
        model.step()
        r_honest = model.r_honest_at_round
        r_byzantine = model.r_byzantine_at_round
        rewards_h += r_honest
        rewards_b += r_byzantine
        rounds_h += [model.counter for _ in range(len(r_honest))]
        rounds_b += [model.counter for _ in range(len(r_byzantine))]

        p.append(model.proportion_of_honest)
        c.append(model.counter)
    rewards_h = np.array(rewards_h) / 100
    rewards_b = np.array(rewards_b) / 100

    plt.scatter(rounds_h, rewards_h, color = 'blue', label = 'rewards of honest')
    plt.scatter(rounds_b, rewards_b, color = 'red', label = 'rewards of byzantine')
    plt.plot(c, p, color = 'green', label = 'proportion of honest')
    ax.legend(loc = 'upper right')
    plt.grid(True)
    
    # x_list = [];
    # step_list = [];
    # model.setup();
    # while model.terminate == False:
    #     # print("not terminated")
    #     model.step();
    #     x_list.append(model.proportion_of_honest);
    #     step_list.append(model.counter);
